# %% [markdown]
# # Early Prediction of Type 2 Diabetes - BEHRT Fine-Tuning
#
# This notebook is responsible for the final predictive pipeline of the thesis. It trains and evaluates a customized **BEHRT (BERT for Electronic Health Records)** model on a binary sequence classification task.
#
# ###  Core Methodological Features:
# * **Data Leakage Prevention:** We implemented strict temporal censoring. The model is forced to predict the future based solely on historical data, as all medical trajectories are explicitly truncated before the diagnosis index date.
# * **Rigorous Class Balancing:** To prevent the model from defaulting to the majority class, the training dataset is dynamically balanced using random undersampling of the healthy cohort. The hold-out test set, however, is left entirely untouched to simulate real-world clinical environments.

# %% [markdown]
# ## Step 1: Set up the Google Colab environment
# We grant access to our files in Drive and install the necessary libraries.

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install the base BEHRT library (older version of HuggingFace)
# !pip install pytorch_pretrained_bert
# Out:
# Mounted at /content/drive
# Collecting pytorch_pretrained_bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl.metadata (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.11.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.0.2)
# Collecting boto3 (from pytorch_pretrained_bert)
#   Downloading boto3-1.43.37-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2025.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Collecting botocore<1.44.0,>=1.43.37 (from boto3->pytorch_pretrained_bert)
#   Downloading botocore-1.43.37-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch_pretrained_bert)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.20.0,>=0.19.0 (from boto3->pytorch_pretrained_bert)
#   Downloading s3transfer-0.19.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (2026.5.20)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.37->boto3->pytorch_pretrained_bert) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=0.4.1->pytorch_pretrained_bert) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.1->pytorch_pretrained_bert) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.1->pytorch_pretrained_bert) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.37->boto3->pytorch_pretrained_bert) (1.17.0)
# Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 14.4 MB/s eta 0:00:00
# Downloading boto3-1.43.37-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 15.4 MB/s eta 0:00:00
# Downloading botocore-1.43.37-py3-none-any.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 101.1 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.19.0-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3, pytorch_pretrained_bert
# Successfully installed boto3-1.43.37 botocore-1.43.37 jmespath-1.1.0 pytorch_pretrained_bert-0.6.2 s3transfer-0.19.0

# %% [markdown]
# ## Step 2: Imports and Paths

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import pickle
from tqdm.notebook import tqdm  # Optimized progress bar for Colab
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score

# --- ABSOLUTE GOOGLE DRIVE PATHS ---
TRAIN_PATH = '/content/drive/MyDrive/Colab Notebooks/BEHRT/data/diabetes_train.parquet'
TEST_PATH = '/content/drive/MyDrive/Colab Notebooks/BEHRT/data/diabetes_test.parquet'
VOCAB_PATH = '/content/drive/MyDrive/Colab Notebooks/BEHRT/data/vocab.pkl'
MODEL_WEIGHTS_PATH = '/content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models/behrt_pretrain_model.pth'

# --- HYPERPARAMETERS ---
MAX_SEQ_LENGTH = 300
BATCH_SIZE = 32
EPOCHS = 4
LEARNING_RATE = 2e-5

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"--- Using processing device: {device} ---")
# Out:
# --- Using processing device: cuda ---

# %% [markdown]
# ## Step 3: Robust Vocabulary Loading
# The model needs to know how to translate a code like 'E11' (Diabetes) into its corresponding numerical ID.

# %%
print("Loading vocabulary...")
with open(VOCAB_PATH, 'rb') as f:
    vocab_obj = pickle.load(f)

if isinstance(vocab_obj, dict) and 'token2idx' in vocab_obj:
    word2idx = vocab_obj['token2idx']
    print("Successfully mapped 'token2idx' as the vocabulary.")
else:
    word2idx = vocab_obj
    print("Warning: 'token2idx' key not found, using raw object as vocabulary.")

VOCAB_SIZE = len(word2idx)
print(f"\nSUCCESS! Vocabulary loaded. Total unique codes in the hospital dataset: {VOCAB_SIZE}")

sep_id = word2idx.get('SEP', -1)
if sep_id == -1:
    print("WARNING: The 'SEP' token was not found in the vocabulary.")
else:
    print(f"'SEP' token correctly identified with ID: {sep_id}")
# Out:
# Loading vocabulary...
# Successfully mapped 'token2idx' as the vocabulary.
#
# SUCCESS! Vocabulary loaded. Total unique codes in the hospital dataset: 52856
# 'SEP' token correctly identified with ID: 8289

# %% [markdown]
# ## Step 4: DataLoader Construction
# This transforms the `.parquet` tables into mathematical tensors that the GPU can process.

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import pandas as pd

class BEHRT_Diabetes_Dataset(Dataset):
    def __init__(self, filepath, word2idx, max_len=300):
        print(f"Reading parquet file: {filepath}...")
        self.df = pd.read_parquet(filepath)
        self.word2idx = word2idx
        self.max_len = max_len
        self.sep_id = self.word2idx.get('SEP', 0)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        codes = row['code']
        ages = row['age'] if 'age' in self.df.columns else [0] * len(codes)
        label = row['label']

        # Truncate to maximum length
        if len(codes) > self.max_len:
            codes = codes[-self.max_len:]
            ages = ages[-self.max_len:]

        # Convert codes to IDs
        # --- SAFETY BELT BOUNDARIES ---
        input_ids = [min(self.word2idx.get(c, 0), VOCAB_SIZE - 1) for c in codes]
        age_ids = [min(int(a) if str(a).isdigit() else 0, 1321) for a in ages]

        # Create Segment IDs (flip between 0 and 1 after each SEP)
        seg_ids = []
        current_seg = 0
        for code_id in input_ids:
            seg_ids.append(current_seg)
            if code_id == self.sep_id:
                current_seg = 1 - current_seg

        attention_mask = [1] * len(input_ids)

        # Padding
        padding_length = self.max_len - len(input_ids)
        if padding_length > 0:
            input_ids = input_ids + [0] * padding_length
            age_ids = age_ids + [0] * padding_length
            seg_ids = seg_ids + [0] * padding_length
            attention_mask = attention_mask + [0] * padding_length

        return {
            'input_ids': torch.tensor(input_ids, dtype=torch.long),
            'age_ids': torch.tensor(age_ids, dtype=torch.long),
            'seg_ids': torch.tensor(seg_ids, dtype=torch.long),
            'attention_mask': torch.tensor(attention_mask, dtype=torch.long),
            'label': torch.tensor(label, dtype=torch.float)
        }

# 1. Load the complete original datasets
train_dataset = BEHRT_Diabetes_Dataset(TRAIN_PATH, word2idx, MAX_SEQ_LENGTH)
test_dataset = BEHRT_Diabetes_Dataset(TEST_PATH, word2idx, MAX_SEQ_LENGTH)

# =====================================================================
# UNDERSAMPLING LOGIC AND STATISTICS (TRAIN SET)
# =====================================================================
print("\n" + "="*50)
print("BALANCING TRAINING DATASET (UNDERSAMPLING)")
print("="*50)

train_labels = train_dataset.df['label'].values
train_idx_class_1 = np.where(train_labels == 1)[0]
train_idx_class_0 = np.where(train_labels == 0)[0]

print("=== ORIGINAL DISTRIBUTION (TRAIN) ===")
print(f"Patients with Diabetes (1): {len(train_idx_class_1)}")
print(f"Patients without Diabetes (0): {len(train_idx_class_0)}")

np.random.seed(42)
train_idx_class_0_downsampled = np.random.choice(train_idx_class_0, size=len(train_idx_class_1), replace=False)

balanced_train_indices = np.concatenate([train_idx_class_1, train_idx_class_0_downsampled])
np.random.shuffle(balanced_train_indices)

balanced_train_dataset = Subset(train_dataset, balanced_train_indices)

print("\n=== DISTRIBUTION AFTER BALANCING (TRAIN) ===")
print(f"Patients with Diabetes (1): {len(train_idx_class_1)}")
print(f"Patients without Diabetes (0): {len(train_idx_class_0_downsampled)}")
print(f"Final total in training: {len(balanced_train_dataset)}")
print("="*50 + "\n")

# =====================================================================
# UNDERSAMPLING LOGIC AND STATISTICS (TEST SET)
# =====================================================================
print("\n" + "="*50)
print("BALANCING TEST DATASET (UNDERSAMPLING)")
print("="*50)

test_labels = test_dataset.df['label'].values
test_idx_class_1 = np.where(test_labels == 1)[0]
test_idx_class_0 = np.where(test_labels == 0)[0]

print("=== ORIGINAL DISTRIBUTION (TEST) ===")
print(f"Patients with Diabetes (1): {len(test_idx_class_1)}")
print(f"Patients without Diabetes (0): {len(test_idx_class_0)}")

np.random.seed(42) # Keep seed for reproducibility
test_idx_class_0_downsampled = np.random.choice(test_idx_class_0, size=len(test_idx_class_1), replace=False)

balanced_test_indices = np.concatenate([test_idx_class_1, test_idx_class_0_downsampled])
np.random.shuffle(balanced_test_indices)

balanced_test_dataset = Subset(test_dataset, balanced_test_indices)

print("\n=== DISTRIBUTION AFTER BALANCING (TEST) ===")
print(f"Patients with Diabetes (1): {len(test_idx_class_1)}")
print(f"Patients without Diabetes (0): {len(test_idx_class_0_downsampled)}")
print(f"Final total in testing: {len(balanced_test_dataset)}")
print("="*50 + "\n")

# =====================================================================
# 2. Create the DataLoaders (Using the balanced train and balanced test)
# =====================================================================
train_loader = DataLoader(balanced_train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(balanced_test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Reading parquet file: /content/drive/MyDrive/Colab Notebooks/BEHRT/data/diabetes_train.parquet...
# Reading parquet file: /content/drive/MyDrive/Colab Notebooks/BEHRT/data/diabetes_test.parquet...
#
# ==================================================
# BALANCING TRAINING DATASET (UNDERSAMPLING)
# ==================================================
# === ORIGINAL DISTRIBUTION (TRAIN) ===
# Patients with Diabetes (1): 14845
# Patients without Diabetes (0): 215318
#
# === DISTRIBUTION AFTER BALANCING (TRAIN) ===
# Patients with Diabetes (1): 14845
# Patients without Diabetes (0): 14845
# Final total in training: 29690
# ==================================================
#
#
# ==================================================
# BALANCING TEST DATASET (UNDERSAMPLING)
# ==================================================
# === ORIGINAL DISTRIBUTION (TEST) ===
# Patients with Diabetes (1): 3711
# Patients without Diabetes (0): 53830
#
# === DISTRIBUTION AFTER BALANCING (TEST) ===
# Patients with Diabetes (1): 3711
# Patients without Diabetes (0): 3711
# Final total in testing: 7422
# ==================================================

# %% [markdown]
# ## Step 5: Load the Pre-trained Model
# We connect the weights from Phase 1 (MLM) to a new linear layer designed for binary classification.

# %%
from pytorch_pretrained_bert import BertConfig, BertForSequenceClassification, BertModel

class BEHRTForSequenceClassification(nn.Module):
    def __init__(self, config, num_labels):
        super().__init__()
        self.bert = BertModel(config)
        # We adjust the size to 1322 so that it is the same as the pre-trained weights
        self.bert.embeddings.age_embeddings = nn.Embedding(1322, config.hidden_size)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, num_labels)

    def forward(self, input_ids, age_ids, seg_ids, attention_mask):
        inputs_embeds = self.bert.embeddings.word_embeddings(input_ids)
        position_embeds = self.bert.embeddings.position_embeddings(
            torch.arange(input_ids.size(1), device=input_ids.device).unsqueeze(0)
        )
        token_type_embeds = self.bert.embeddings.token_type_embeddings(seg_ids)

        age_embeds = self.bert.embeddings.age_embeddings(age_ids)

        embeddings = inputs_embeds + position_embeds + token_type_embeds + age_embeds
        embeddings = self.bert.embeddings.LayerNorm(embeddings)
        embeddings = self.bert.embeddings.dropout(embeddings)

        # CHANGE: we capture the result without forcing the unpackaging of two variables
        encoder_output = self.bert.encoder(embeddings, attention_mask.unsqueeze(1).unsqueeze(2))

        # If it returns a tuple, the first element usually is a list of layers (or the final tensor)
        if isinstance(encoder_output, tuple):
            sequence_output = encoder_output[0]
        else:
            sequence_output = encoder_output

        # If sequence_output is a list (list of layers), we take the last layer [-1]
        if isinstance(sequence_output, list):
            final_layer = sequence_output[-1]
        else:
            final_layer = sequence_output

        pooled_output = self.bert.pooler(final_layer)

        pooled_output = self.dropout(pooled_output)
        return self.classifier(pooled_output)

# Configuration...
config = BertConfig(
    vocab_size_or_config_json_file=VOCAB_SIZE,
    hidden_size=288, num_hidden_layers=6, num_attention_heads=12,
    intermediate_size=512, hidden_act="gelu", hidden_dropout_prob=0.1,
    attention_probs_dropout_prob=0.1, max_position_embeddings=512
)

model = BEHRTForSequenceClassification(config, num_labels=1)

# Load weights
state_dict = torch.load(MODEL_WEIGHTS_PATH, map_location=device)

# Load the model
model.load_state_dict(state_dict, strict=False)
model.to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
criterion = nn.BCEWithLogitsLoss()
print("Model ready!")
# Out:
# Model ready!

# %% [markdown]
# ## Step 6: Training (Fine-Tuning)
# We fine-tune the model exclusively on the task of reading early historical context to predict incident diabetes.

# %%
import os
import torch

# Create a folder in your Drive to prevent data loss if it stops
save_dir = '/content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models'
os.makedirs(save_dir, exist_ok=True)

print("========================================================")
print("STARTING FINE-TUNING (DIABETES PREDICTION)")
print("========================================================")

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0

    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} [Training]")

    for batch in progress_bar:
        b_input_ids = batch['input_ids'].to(device)
        b_age_ids = batch['age_ids'].to(device)
        b_seg_ids = batch['seg_ids'].to(device)
        b_mask = batch['attention_mask'].to(device)
        b_labels = batch['label'].to(device)

        model.zero_grad()

        outputs = model(b_input_ids, age_ids=b_age_ids, seg_ids=b_seg_ids, attention_mask=b_mask)
        logits = outputs[0] if isinstance(outputs, tuple) else outputs
        logits = logits.squeeze(-1) # Flatten tensor

        loss = criterion(logits, b_labels)
        total_loss += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # Mathematical stability to prevent exploding gradients
        optimizer.step()

        progress_bar.set_postfix({'loss': f"{loss.item():.4f}"})

    avg_train_loss = total_loss / len(train_loader)
    print(f"---> Epoch {epoch+1} Completed | Average Training Loss: {avg_train_loss:.4f}\n")

    # --- AUTOMATIC SAVING ---
    checkpoint_path = os.path.join(save_dir, f'balanced_diabetes_model_epoch_{epoch+1}.pth')
    torch.save(model.state_dict(), checkpoint_path)
    print(f"Checkpoint for epoch {epoch+1} successfully saved at: {checkpoint_path}\n")
# Out:
# ========================================================
# STARTING FINE-TUNING (DIABETES PREDICTION)
# ========================================================
# Epoch 1/4 [Training]:   0%|          | 0/928 [00:00<?, ?it/s]
# ---> Epoch 1 Completed | Average Training Loss: 0.2486
#
# Checkpoint for epoch 1 successfully saved at: /content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models/balanced_diabetes_model_epoch_1.pth
# Epoch 2/4 [Training]:   0%|          | 0/928 [00:00<?, ?it/s]
# ---> Epoch 2 Completed | Average Training Loss: 0.1551
#
# Checkpoint for epoch 2 successfully saved at: /content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models/balanced_diabetes_model_epoch_2.pth
# Epoch 3/4 [Training]:   0%|          | 0/928 [00:00<?, ?it/s]
# ---> Epoch 3 Completed | Average Training Loss: 0.1328
#
# Checkpoint for epoch 3 successfully saved at: /content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models/balanced_diabetes_model_epoch_3.pth
# Epoch 4/4 [Training]:   0%|          | 0/928 [00:00<?, ?it/s]
# ---> Epoch 4 Completed | Average Training Loss: 0.1135
#
# Checkpoint for epoch 4 successfully saved at: /content/drive/MyDrive/Colab Notebooks/BEHRT/saved_models/balanced_diabetes_model_epoch_4.pth

# %% [markdown]
# ## Step 7: The Final Exam (Test Set Evaluation)
# We evaluate the model on patients it has never seen and calculate the scientific metrics for the thesis report.

# %%
import os
import numpy as np
import torch
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, confusion_matrix
from tqdm import tqdm

# 1. Create a folder for final results in your Google Drive
results_dir = '/content/drive/MyDrive/Colab Notebooks/BEHRT/results'
os.makedirs(results_dir, exist_ok=True)

print("========================================================")
print("EVALUATING BALANCED MODEL ON TEST SET")
print("========================================================")

model.eval()
all_preds = []
all_probs = []
all_labels = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        b_input_ids = batch['input_ids'].to(device)
        b_age_ids = batch['age_ids'].to(device)
        b_seg_ids = batch['seg_ids'].to(device)
        b_mask = batch['attention_mask'].to(device)
        b_labels = batch['label'].cpu().numpy()

        outputs = model(b_input_ids, age_ids=b_age_ids, seg_ids=b_seg_ids, attention_mask=b_mask)
        logits = outputs[0] if isinstance(outputs, tuple) else outputs
        logits = logits.squeeze(-1)

        # We use Sigmoid to convert logits into probabilities between 0 and 1
        probs = torch.sigmoid(logits).cpu().numpy()
        preds = (probs > 0.5).astype(int)

        all_probs.extend(probs)
        all_preds.extend(preds)
        all_labels.extend(b_labels)

# --- PANIC-PROOF SAVING ---
np.save(os.path.join(results_dir, 'all_labels.npy'), all_labels)
np.save(os.path.join(results_dir, 'all_preds.npy'), all_preds)

# --- CALCULATING METRICS ---
auc_roc = roc_auc_score(all_labels, all_probs)
f1 = f1_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds)
recall = recall_score(all_labels, all_preds)

# Calculate Specificity from Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
TN, FP, FN, TP = cm.ravel()
specificity = TN / (TN + FP)

print("\n========================================================")
print("FINAL SCIENTIFIC RESULTS (INCIDENT DISEASE PREDICTION)")
print("========================================================")
print(f"ROC-AUC Score : {auc_roc:.4f} (Ability to rank patient risk correctly)")
print(f"F1-Score      : {f1:.4f} (Harmonic mean of Precision and Recall)")
print(f"Precision     : {precision:.4f} (Out of all predicted diabetics, how many were true diabetics?)")
print(f"Recall        : {recall:.4f} (Out of all true diabetics, how many did the model catch?)")
print(f"Specificity   : {specificity:.4f} (Out of all true healthy patients, how many were predicted healthy?)")
print("========================================================")
# Out:
# ========================================================
# EVALUATING BALANCED MODEL ON TEST SET
# ========================================================
# Evaluating: 100%|██████████| 232/232 [00:22<00:00, 10.10it/s]
# ========================================================
# FINAL SCIENTIFIC RESULTS (INCIDENT DISEASE PREDICTION)
# ========================================================
# ROC-AUC Score : 0.9834 (Ability to rank patient risk correctly)
# F1-Score      : 0.9385 (Harmonic mean of Precision and Recall)
# Precision     : 0.9463 (Out of all predicted diabetics, how many were true diabetics?)
# Recall        : 0.9307 (Out of all true diabetics, how many did the model catch?)
# Specificity   : 0.9472 (Out of all true healthy patients, how many were predicted healthy?)
# ========================================================

# %% [markdown]
# ## Step 8: The Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

results_dir = '/content/drive/MyDrive/Colab Notebooks/BEHRT/results'

# Reuse the confusion matrix 'cm' calculated in the previous cell
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Healthy (0)', 'Predicted Diabetic (1)'],
            yticklabels=['True Healthy (0)', 'True Diabetic (1)'],
            annot_kws={"size": 14})

plt.title('Confusion Matrix - Type 2 Diabetes Prediction', fontsize=16, pad=15)
plt.xlabel('Model Prediction', fontsize=14, labelpad=10)
plt.ylabel('Actual Ground Truth', fontsize=14, labelpad=10)
plt.tight_layout()

# Save image directly to Google Drive
cm_path = os.path.join(results_dir, 'balanced_confusion_matrix.png')
plt.savefig(cm_path, dpi=300)
plt.show()

print(f" Confusion matrix successfully generated and saved at: {cm_path}")
# Out:
#  Confusion matrix successfully generated and saved at: /content/drive/MyDrive/Colab Notebooks/BEHRT/results/balanced_confusion_matrix.png
